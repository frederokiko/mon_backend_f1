# %%
## Import libraries
import numpy as np
import pandas as pd

# %% [markdown]
# importer pit_stop_ok

# %%
pit_stop_df = pd.read_csv('./pit_stops_ok.csv')

# %%
pit_stop_df.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
pit_stop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11030 entries, 0 to 11029
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   raceId        11030 non-null  int64
#  1   driverId      11030 non-null  int64
#  2   stop          11030 non-null  int64
#  3   lap           11030 non-null  int64
#  4   time          11030 non-null  object
#  5   duration      11030 non-null  object
#  6   milliseconds  11030 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 603.3+ KB

# %% [markdown]
# importer qualifying_ok.csv

# %%
qualifying_df = pd.read_csv('./qualifying_ok.csv')

# %%
qualifying_df.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
qualifying_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10274 entries, 0 to 10273
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   qualifyId      10274 non-null  int64
#  1   raceId         10274 non-null  int64
#  2   driverId       10274 non-null  int64
#  3   constructorId  10274 non-null  int64
#  4   number         10274 non-null  int64
#  5   position       10274 non-null  int64
#  6   q1             10274 non-null  object
#  7   q2             10261 non-null  object
#  8   q3             10247 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 722.5+ KB

# %% [markdown]
# importer results.csv

# %%
results_df = pd.read_csv('./results.csv')

# %%
results_df.head(20)
# Out:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 0          1      18         1              1     22     1        1
# 1          2      18         2              2      3     5        2
# 2          3      18         3              3      7     7        3
# 3          4      18         4              4      5    11        4
# 4          5      18         5              1     23     3        5
# 5          6      18         6              3      8    13        6
# 6          7      18         7              5     14    17        7
# 7          8      18         8              6      1    15        8
# 8          9      18         9              2      4     2       \N
# 9         10      18        10              7     12    18       \N
# 10        11      18        11              8     18    19       \N
# 11        12      18        12              4      6    20       \N
# 12        13      18        13              6      2     4       \N
# ...

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26539 entries, 0 to 26538
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26539 non-null  int64
#  1   raceId           26539 non-null  int64
#  2   driverId         26539 non-null  int64
#  3   constructorId    26539 non-null  int64
#  4   number           26539 non-null  object
#  5   grid             26539 non-null  int64
#  6   position         26539 non-null  object
#  7   positionText     26539 non-null  object
#  8   positionOrder    26539 non-null  int64
#  9   points           26539 non-null  float64
#  10  laps             26539 non-null  int64
#  11  time             26539 non-null  object
#  12  milliseconds     26539 non-null  object
#  13  fastestLap       26539 non-null  object
#  14  rank             26539 non-null  object
#  15  fastestLapTime   26539 non-null  object
#  16  fastestLapSpeed  26539 non-null  object
# ...

# %%
results_df.to_csv('results_ok.csv')

# %% [markdown]
# importer seasons et trier

# %%
seasons_df = pd.read_csv('./seasons.csv')

# %%
seasons_df.head()
# Out:
#    year                                                url
# 0  2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1  2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2  2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3  2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4  2005  http://en.wikipedia.org/wiki/2005_Formula_One_...

# %%
seasons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    75 non-null     int64
#  1   url     75 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.3+ KB

# %%
seasons_df.to_csv('seasons_ok.csv')

# %% [markdown]
# importer sprint_results

# %%
sprint_results_df = pd.read_csv('./sprint_results.csv')

# %%
sprint_results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid position  \
# 0         1    1061       830              9      33     2        1
# 1         2    1061         1            131      44     1        2
# 2         3    1061       822            131      77     3        3
# 3         4    1061       844              6      16     4        4
# 4         5    1061       846              1       4     6        5
#
#   positionText  positionOrder  points  laps       time milliseconds  \
# 0            1              1       3    17  25:38.426      1538426
# 1            2              2       2    17     +1.430      1539856
# 2            3              3       1    17     +7.502      1545928
# 3            4              4       0    17    +11.278      1549704
# 4            5              5       0    17    +24.111      1562537
#
#   fastestLap fastestLapTime  statusId
# 0         14       1:30.013         1
# 1         17       1:29.937         1
# ...

# %% [markdown]
# Je ne vais pas utiliser ce fichier !!!

# %% [markdown]
# voir status

# %%
status_df = pd.read_csv('./status_ok.csv')

# %%
status_df.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
status_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   statusId  139 non-null    int64
#  1   status    139 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB
